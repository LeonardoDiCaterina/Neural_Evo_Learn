# %%
import os

os.chdir(os.path.join(os.getcwd(), os.pardir))
from utils.visualization_funcs import *
from utils.final_visualizations_funcs import *
# %cd notebooks/
# Out:
# c:\Users\irism\OneDrive - NOVAIMS\Msc-NEL\Neural_Evo_Learn\notebooks

# %%
train_test_all_box(model_names=['GP', 'GSGP', 'SLIM-GSGP', 'NN', 'SLIM-GSGP'])

# %%
evolution_plots_all(k_outer=10, model_names=['GP', 'GSGP', 'SLIM-GSGP', 'NN'], show_train=True, show_test=True)

# %%
evolution_plots_all(k_outer=10, model_names=['GP', 'GSGP', 'SLIM-GSGP', 'NN'], show_train=False, show_test=True)
