# %% [markdown]
# # Neural and Evolutionary Leaning Project
#
# Group members:
#
# - Iris Moreira - 20240659
# - Leonardo Di Caterina - 20240485
# - Rafael Borges - 20240497
#
# ## Third Delivery - SLIM-GSGP

# %%
#! git clone https://github.com/LeonardoDiCaterina/Neural_Evo_Learn

# %%
#! pip install git+https://github.com/DALabNOVA/slim.git

# %%
# Third-party imports
import pandas as pd
import torch
from sklearn.model_selection import KFold

# Slim-GSGP imports
from slim_gsgp.datasets.data_loader import load_pandas_df
from slim_gsgp.utils.utils import train_test_split
#from slim_gsgp.main_gp import gp
#from slim_gsgp.main_gsgp import gsgp
from slim_gsgp.main_slim import slim
from slim_gsgp.evaluators.fitness_functions import rmse

import statistics
from collections import defaultdict
import itertools

from sklearn.model_selection import KFold
import numpy as np
import os
import random
from itertools import product

# %%
os.chdir(os.path.join(os.getcwd(), os.pardir))
from utils.grid_search import gp_nested_cross_validation
from utils.visualization_funcs import *
# %cd notebooks/
# Out:
# c:\Users\irism\OneDrive - NOVAIMS\Msc-NEL\Neural_Evo_Learn\notebooks

# %% [markdown]
# ## Load Data

# %%
# Reading the desired dataset
df = pd.read_csv("../data/sustavianfeed.csv", sep=';')

# Dropping the first column (index) and renaming the columns
df = df.drop(columns= ['WING TAG', 'EMPTY MUSCULAR STOMACH'])

# Moving crude protein to the end of the dataframe
df = df[[col for col in df.columns if col != 'CRUDE PROTEIN'] + ['CRUDE PROTEIN']]

# %% [markdown]
# # Nested CV with Grid Search

# %%
seed = 42
random.seed(seed)

# Edit the name and log directory based on the model you want to run

#MODEL_NAME = 'GP'
#MODEL_NAME = 'GSGP'
MODEL_NAME = 'SLIM-GSGP_3'

DATASET_NAME = MODEL_NAME +'_sustavianfeed'
LOG_DIR = './log/' + MODEL_NAME + '/'

LOG_LEVEL = 2
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)

# %%
k_outer = 10
k_inner = 5

# %%
# Turning df into X and y torch.Tensors
X, y = load_pandas_df(df, X_y=True)

# %%
FITNESS_FUNCTION = 'rmse'
MINIMIZATION = True

total_instances = X.shape[0]
outer_test_size = total_instances // k_outer
outer_train_size = total_instances - outer_test_size
inner_val_size = outer_train_size // k_inner
inner_train_size = outer_train_size - inner_val_size

print(f'Total Instances:\t{total_instances}\n--')
print(f'Outer Train set:\t{outer_train_size}')
print(f'Test set:\t\t{outer_test_size}\n--')
print(f'Inner Train set:\t{inner_train_size}')
print(f'Validation set:\t\t{inner_val_size}\n')
# Out:
# Total Instances:	96
# --
# Outer Train set:	87
# Test set:		9
# --
# Inner Train set:	70
# Validation set:		17

# %%
POP_SIZE = 50

fixed_params = {
    # ---
    # Search Space
    'initializer': 'rhh',
    'init_depth': 2,
    'tree_constants': [random.uniform(-1, 1) for _ in range(9)],
    'tree_functions': ['add', 'subtract','multiply','divide'],
    #'prob_const': 0.1,
    # ---
    # Problem Instance
    'dataset_name': DATASET_NAME,
    'fitness_function': 'rmse',
    'minimization': True,
    # ---
    # Model instance
    #'tournament_size': int(POP_SIZE*0.02) if POP_SIZE>100 else 2,
    'pop_size': POP_SIZE,
    'ms_lower': 0,
    'ms_upper': 0.5,


    # ---
    # Solve settings
    'n_iter': 250,
    'elitism': True,
    'n_elites': 2,
    'test_elite': True,
    'log_level': LOG_LEVEL,
    'verbose': 0,
    'n_jobs': 1,

    # ---
    # GP unique settings
    #'max_depth': 10,
    #'p_xo' : 0.5,


    # ---
    # GSGP unique settings
    #'p_xo' : 0.5,
    
    #'reconstruct': False,


    # ---
    # SLIM unique settings
    #'max_depth': 10,
    #'#p_inflate': 0.70,
    #'copy_parent': True,
    #'reconstruct': False,


}


param_grid = {

        'max_depth': [10, 15],
        'tournament_size': [int(POP_SIZE*0.05), int(POP_SIZE*0.10), int(POP_SIZE*0.15)],
        'prob_const': [0.1,0.45, 0.7],
        'slim_version':  ['SLIM*SIG1', 'SLIM*ABS'],
}

# %%
outer_results = gp_nested_cross_validation(X, y, gp_model=slim, k_outer=k_outer, k_inner=k_inner, fixed_params=fixed_params, param_grid=param_grid, seed=seed, LOG_DIR=LOG_DIR, DATASET_NAME=DATASET_NAME)
# Out:
# Outer fold 1/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([68, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 2, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 8.01662826538086
# Training best combination on entire learning set
# Outer fold 2/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([68, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 2, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 8.02702808380127
# Training best combination on entire learning set
# Outer fold 3/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([68, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 15, 'tournament_size': 2, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 7.942052841186523
# Training best combination on entire learning set
# Outer fold 4/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([68, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 5, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 10.037054061889648
# Training best combination on entire learning set
# Outer fold 5/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([68, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 5, 'prob_const': 0.7, 'slim_version': 'SLIM*SIG1'} with median RMSE: 8.995772361755371
# Training best combination on entire learning set
# Outer fold 6/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([68, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 2, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 7.843826770782471
# Training best combination on entire learning set
# Outer fold 7/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 5, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 8.711589813232422
# Training best combination on entire learning set
# Outer fold 8/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 5, 'prob_const': 0.7, 'slim_version': 'SLIM*SIG1'} with median RMSE: 8.423811912536621
# Training best combination on entire learning set
# Outer fold 9/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 5, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 8.424755096435547
# Training best combination on entire learning set
# Outer fold 10/10
# -----
#  Inner fold 1/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 2/5
# Training shape: torch.Size([69, 12])
# Validation shape: torch.Size([18, 12])
#
# -----
#  Inner fold 3/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 4/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# -----
#  Inner fold 5/5
# Training shape: torch.Size([70, 12])
# Validation shape: torch.Size([17, 12])
#
# Best inner combination: {'max_depth': 10, 'tournament_size': 5, 'prob_const': 0.7, 'slim_version': 'SLIM*ABS'} with median RMSE: 8.603760719299316
# Training best combination on entire learning set

# %% [markdown]
# Saving results and configs to a .csv

# %%
outer_results_df = pd.DataFrame(outer_results)
outer_results_df.to_csv(LOG_DIR+DATASET_NAME+'_outer_results.csv', index=False)

# %% [markdown]
# ## Visualizations

# %%
train_test_best_combs(model_name=MODEL_NAME)

# %%
test_best_combs(model_name=MODEL_NAME)

# %%
fit_and_size_per_outer(k_outer=10, model_name=MODEL_NAME)

# %% [markdown]
# ## Brief Bloat and Overfitting Discussion
#
# - For every hyper-parameter setting we tried, the RMSE plateaus after roughly 100–200 iterations, yet the program trees keep growing. That continued growth—typical of GSGP—signals classic bloating.
#
# - Signs of overfitting are inconclusive: some runs show the expected pattern (training RMSE < test RMSE), while others reverse it (test RMSE < training RMSE). The conflicting results are probably a side-effect of the small dataset.

# %%
fit_and_size_per_comb(10,MODEL_NAME,n_rows=3,n_cols=1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fit_and_size_per_comb(10,MODEL_NAME,n_rows=3,n_cols=1)
#
# File c:\Users\irism\OneDrive - NOVAIMS\Msc-NEL\Neural_Evo_Learn\utils\visualization_funcs.py:338, in fit_and_size_per_comb(k_outer, model_name, n_rows, n_cols, size)
#     333 df_log = pd.concat(df_log, ignore_index=True)
#     335 unique_comb_list = list(set(comb_list))
#     337 assert (
# --> 338     len(unique_comb_list) == n_rows * n_cols
#     339 ), "The number of combinations does not correspond to the grid size defined (rows/cols)."
#     341 make_evolution_plots(
#     342     n_rows=n_rows,
#     343     n_cols=n_cols,
#    (...)
#     346     plot_title=f"{model_name} - Train vs Test Fitness",
#     347 )
#     349 if size:
#
# AssertionError: The number of combinations does not correspond to the grid size defined (rows/cols).

# %%
pop_fitness_diversity(10, MODEL_NAME)

# %% [markdown]
# ## Early Convergence Discussion
#
# - The final plots reveal a sharp drop in population diversity during the first few iterations, likely a consequence of the small population size used in the grid search combined with tournament selection. Selection pressure need to be reviewed

# %% [markdown]
# ## Future Work
#
# - Increase population size
# - Review selection pressure
